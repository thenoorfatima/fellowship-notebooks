# %%
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 745 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 24.6 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 428 kB 68.4 MB/s
# ...
#      |████████████████████████████████| 394 kB 57.3 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 125 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 124 kB 58.4 MB/s
# ...
#      |████████████████████████████████| 124 kB 50.5 MB/s
# ...
#      |████████████████████████████████| 122 kB 57.3 MB/s
# ...
#      |████████████████████████████████| 122 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 122 kB 67.3 MB/s
# ...
#      |████████████████████████████████| 122 kB 60.4 MB/s
# ...
#      |████████████████████████████████| 112 kB 48.4 MB/s
# ...

# %%
 from colabcode import ColabCode
 ColabCode(port=10000, password="ok")
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://b1c4-34-73-148-143.ngrok.io" -> "http://localhost:10000"
# [2021-11-04T07:42:08.651Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-11-04T07:42:08.653Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-11-04T07:42:08.678Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-11-04T07:42:08.678Z] info  HTTP server listening on http://127.0.0.1:10000
# [2021-11-04T07:42:08.678Z] info    - Authentication is enabled
# [2021-11-04T07:42:08.678Z] info      - Using password from $PASSWORD
# [2021-11-04T07:42:08.678Z] info    - Not serving HTTPS

# %%
rasa init
